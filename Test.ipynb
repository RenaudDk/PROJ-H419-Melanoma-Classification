# %% [markdown]
# ### TEST

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import numpy as np

# %%
from sklearn import datasets
iris = datasets.load_iris()
digits = datasets.load_digits()
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
a = np.arange(6)
print(a)
# Out:
# [0 1 2 3 4 5]

# %%
import os
import tensorflow as tf
import cv2

# %%
#Sur tour
train_csv_path = r'C:\Users\renau\Desktop\DATA\data_proj_melanoma\train.csv'
test_csv_path = r'C:\Users\renau\Desktop\DATA\data_proj_melanoma\test.csv'
train_jgp_path = r"C:\Users\renau\Desktop\DATA\data_proj_melanoma\jpeg\train\ISIC_2637011.jpg"
list(os.listdir(r'C:\Users\renau\Desktop\DATA\data_proj_melanoma'))
# Out:
# ['jpeg',
#  'sample_submission.csv',
#  'test',
#  'test.csv',
#  'tfrecords',
#  'train',
#  'train.csv']

# %%
train_csv = pd.read_csv(train_csv_path) 
train_csv.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0

# %%
test_csv = pd.read_csv(test_csv_path) 
test_csv.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge
# 0  ISIC_0052060  IP_3579794    male        70.0                           NaN
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity

# %%
from  matplotlib import pyplot as plt
import random
import matplotlib.image as mpimg
# %matplotlib inline

plt.figure(figsize=(20,20))
img_folder=r"C:\Users\renau\Desktop\DATA\data_proj_melanoma\jpeg\train"
for i in range(5):
    file = random.choice(os.listdir(img_folder))
    image_path= os.path.join(img_folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)
